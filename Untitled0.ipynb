# %% [markdown]
# <a href="https://colab.research.google.com/github/naitikkumar031-cloud/Generative-AI/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
x = 10
x
# Out:
# 10

# %%
n = 7936
d = 0
sum = 0
while n>0:
  d = n%10
  sum = sum + d
  n = n//10
print(sum)
# Out:
# 25

# %%
_mycity = "solan"
_mycity
# Out:
# 'solan'

# %%
mysub = "python"
print(mysub)
# Out:
# python

# %%
mysub1 = "Generative AI"
mysub1
# Out:
# 'Generative AI'

# %%
1mysub = "Machine Learning"
1mysub
# Out:
#   File "/tmp/ipython-input-697298423.py", line 1
#     1mysub = "Machine Learning"
#     ^
# SyntaxError: invalid decimal literal

# %% [markdown]
# Rules for variable naming
# - Not to use numbers in first position while naming the variable
# - space,symbol,keywords cannot be used for the variable

# %%
import keyword
print(keyword.kwlist)
# Out:
# ['False', 'None', 'True', 'and', 'as', 'assert', 'async', 'await', 'break', 'class', 'continue', 'def', 'del', 'elif', 'else', 'except', 'finally', 'for', 'from', 'global', 'if', 'import', 'in', 'is', 'lambda', 'nonlocal', 'not', 'or', 'pass', 'raise', 'return', 'try', 'while', 'with', 'yield']

# %% [markdown]
# Data Type

# %%
# Numeric
# integer --- Absence of decimal point is known as integer
# Ex -- 1,2,,3,4...
x = 1
type(x)
# Out:
# int

# %%
# Floating point number --- Presence of decimal point
# Ex -- 2.14,3.89,0.0
y = 0.0
type(y)
# Out:
# float

# %%
# Complex --- Combination of real and imaginary
# Ex -- 5 + 7j
z = 3 + 4j
type(z)
# Out:
# complex

# %%
# String --- Data in the form of text
x = "Solan"
type(x)
# Out:
# str

# %%
# Boolean --- Used to store value in true and false
a = True
type(a)
# Out:
# bool

# %%
b = False
type(b)
# Out:
# bool

# %%
# None --- Define a null value
e = None
type(e)
# Out:
# NoneType

# %%
# Single quote string
my_sub = 'Generative AI'
type(my_sub)
# Out:
# str

# %%
# Double quote string
my_college = "Shoolini University"
type(my_college)
# Out:
# str

# %%
# Triple quote string
my_sentence = '''This is a multi line sentence,
                 it is also known as string'''
type(my_sentence)
# Out:
# str

# %%
my_sub = "Machine Learning"
print(my_sub)
# Out:
# Machine Learning

# %%
#len() --- It is a function to find the length of the string
len(my_sub)
# Out:
# 16

# %% [markdown]
# String Indexing

# %%
my_sub[0]
# Out:
# 'M'

# %%
my_sub[-3]
# Out:
# 'i'

# %% [markdown]
# String Slicing

# %%
my_sub[3:7:1]
# Out:
# 'hine'

# %%
my_sub[2:13:1]
# Out:
# 'chine Learn'

# %%
# Step-size is optional
# By default step-size is one
my_sub[0:14]
# Out:
# 'Machine Learni'

# %%
my_sub[:]
# Out:
# 'Machine Learning'

# %%
# lower() --- This metod converts the string into lower case
my_sub = "PYTHON"
my_sub.lower()
# Out:
# 'python'

# %%
# upper() --- This method converts the string into upper case
my_sub = "machine learning"
my_sub.upper()
# Out:
# 'MACHINE LEARNING'

# %%
# count() --- This method is used to determine the number of
#             occurrences of a specific value within a string
my_sub = "machine learning"
my_sub.count('a')
# Out:
# 2

# %%
# This shows how many times Ne occurs
algorithm = "Neural Network"
algorithm.count('Ne')
# Out:
# 2

# %%
# find() --- this method returns the index of the first occurrence
algorithm.find('k')
# Out:
# 13

# %%
algorithm.replace(" ",'-')
# Out:
# 'Neural-Network'

# %% [markdown]
#  List
#  - It is a collection of items and every item separated by commas constructed within the brackets

# %%
# Homogeneous List --- Contains same type of data
my_list = [79,23,4,5,6,88]
type(my_list)
# Out:
# list

# %%
# Heterogeneous List --- Contains different type of data
mixed_list = [76,2.14,"apple",True,None]
type(mixed_list)
# Out:
# list

# %% [markdown]
# Indexing in List
# - Refer to the location of an element

# %%
# Positive Indexing
my_list = [78,54,32,89,23]
print(my_list[0])
print(my_list[1])
print(my_list[2])
print(my_list[3])
print(my_list[4])
# Out:
# 78
# 54
# 32
# 89
# 23

# %%
# Negative Indexing
print(my_list[-1])
print(my_list[-2])
print(my_list[-3])
print(my_list[-4])
print(my_list[-5])
# Out:
# 23
# 89
# 32
# 54
# 78

# %% [markdown]
# Slicing in List
# - Grab the data upto designated point is known as slicing

# %%
my_list = [98,78,56,34,48]
my_list[0:4:1]
# Out:
# [98, 78, 56, 34]

# %%
my_list[:]
# Out:
# [98, 78, 56, 34, 48]

# %%
my_list[0:]
# Out:
# [98, 78, 56, 34, 48]

# %%
my_list[:4]
# Out:
# [98, 78, 56, 34]

# %%
my_list[: :-1]
# Out:
# [48, 34, 56, 78, 98]

# %% [markdown]
# List Properties

# %%
# Mutability --- After construction of list we can change it
my_list = [100,79,49,50,97]
my_list[0] = 500
my_list
# Out:
# [500, 79, 49, 50, 97]

# %%
# Concatenation --- Addition of List
list1 = [79,89,400]
list2 = [500,79,89]
my_list = list1 + list2
my_list
# Out:
# [79, 89, 400, 500, 79, 89]

# %% [markdown]
# List Functions

# %%
# len() --- This function returns the length of the list
my_list = [7,8,9,10]
len(my_list)
# Out:
# 4

# %% [markdown]
# This function only works with list of similar data type
# - min()
# - max()
# - sum()
# - sorted()

# %%
# min() --- This function returns the minimum element of the list
my_list = [78,21,24,99,23]
min(my_list)
# Out:
# 21

# %%
# max() --- This function returns the maximum element of list
max(my_list)
# Out:
# 99

# %%
# sum() --- This function returns the sum of the element of the list
my_list = [4,5,6,2,3]
sum(my_list)
# Out:
# 20

# %%
# sorted() --- This function returns the sorted list means increasing
#              or decreasing order
# sorted() function takes reverse boolean as an argument
# This function does not change our list
my_list = [4,7,8,10,11]
sorted(my_list, reverse = True)
# Out:
# [11, 10, 8, 7, 4]

# %% [markdown]
# List Methods

# %%
# append() --- This method is use to permanently add an item to the end
#              of the list
# It changes the original list
my_list = [4,5,6,2,3]
my_list.append(9)
my_list
# Out:
# [4, 5, 6, 2, 3, 9]

# %%
#extend() --- This method is use to merge a list to an existing list
# It takes a list or any iterable as an argument
my_list = [4,5,6,2,3]
my_list.extend(['Jagat','apple'])
(my_list)
# Out:
# [4, 5, 6, 2, 3, 'Jagat', 'apple']

# %%
# pop() --- It is use to 'pop off' an item from the list
# By default it takes off the element at the last index, but you also
# specify which index to pop off
# It takes the index as an argument and returns the element which was
# popped off
my_list = [1,2,3,4,5]
my_list.pop()
# Out:
# 5

# %%
# remove() --- This method is use to remove an item from the list
# By default it removes the specified element from the list
# It takes the element as an argument
my_list = [1,2,3,4,5]
my_list.remove(5)
my_list
# Out:
# [1, 2, 3, 4]

# %%
# count() --- This method returns the total occurrence of a specified
#             element in the list
my_list = [1,2,1,1,3,1,4,1]
my_list.count(1)
# Out:
# 5

# %%
# index() --- This method returns the index of a specified element
my_list = [4,5,6,7,8]
my_list.index(4)
# Out:
# 0

# %% [markdown]
# sort()
# - This method is use to sort the list in either ascending/descending order
# - By default the sorting is done in ascending order
# - It takes the reverse boolean as an argument
# - This method only works on a list with element of same data type

# %%
new_list = [6,9,1,3,5]
new_list.sort()
new_list
# Out:
# [1, 3, 5, 6, 9]

# %%
# reverse() --- This method reverse the list
my_list = [4,5,6,2,3]
my_list.reverse()
my_list
# Out:
# [3, 2, 6, 5, 4]

# %% [markdown]
# Nested Lists
# - A great feature of python data structures is that they support nesting
# - This mean we can have data structures within data structure

# %%
list1 = [1,2,3]
list2 = [4,5,6]
list3 = [7,8,9]
list_of_list = [list1,list2,list3]
print(list_of_list)
# Out:
# [[1, 2, 3], [4, 5, 6], [7, 8, 9]]

# %%
# indexing
list_of_list [0][1]
# Out:
# 2

# %% [markdown]
# Tuples

# %% [markdown]
# Dictionary
# - It is a collection of 'key-value' pair
# - A dictionary object is constructed by using curly braces
# - { key1:value1, key2:value2, key3:value3 }

# %%
my_dict = { "UP":"LUCK", "RAJ":"JAI", "PUN":"CHA" }
type(my_dict)
# Out:
# dict

# %%
my_dict["UP"]
# Out:
# 'LUCK'

# %%
my_dict["RAJ"]
# Out:
# 'JAI'

# %%
my_dict["PUN"]
# Out:
# 'CHA'

# %% [markdown]
# Dictionary Method

# %%
# keys() --- This method returns the list of keys in the dictionary object
my_dict.keys()
# Out:
# dict_keys(['UP', 'RAJ', 'PUN'])

# %%
# values() --- This method returns the list of values in the dictionary
#              object
my_dict.values()
# Out:
# dict_values(['LUCK', 'JAI', 'CHA'])

# %%
# items() --- This method returns the list of the keys and values
list(my_dict.items())
# Out:
# [('UP', 'LUCK'), ('RAJ', 'JAI'), ('PUN', 'CHA')]

# %% [markdown]
# get()
# - This method is use to extract a particular value of the key-value pair
# - This method takes the key as an argument and returns None if the key is not found in the dictionary
# - We can also set the value to return if key is not found
# - This will be passed as the second argument in get()

# %%
my_dict = {"UP":"LUCK", "RAJ":"JAI"}
my_dict.get("UP")
# Out:
# 'LUCK'

# %%
my_dict.get("HP")

# %%
my_dict.get("HP", "Not Found")
# Out:
# 'Not Found'

# %% [markdown]
# It is important to note that dictionaries are very flexible in the data types they can hold
# - my_dict = { "Name" : "Willam", "list1" : [1,2,3,4] }

# %%
# update() --- It adds an element which is key-value pair
#              This method takes a dictionary as an argument
my_dict = {"Name":"Willam", "list1":[1,2,3,4]}
my_dict.update({"College" : "IIT Mandi"})
print(my_dict)
# Out:
# {'Name': 'Willam', 'list1': [1, 2, 3, 4], 'College': 'IIT Mandi'}

# %%
# We can also use update() method to update the existing value for a key
my_dict.update({"Name":"Navodita"})
my_dict
# Out:
# {'Name': 'Navodita', 'list1': [1, 2, 3, 4], 'College': 'IIT Mandi'}

# %% [markdown]
# dict()
# - We can also create dictionary objects from sequence of items which are pairs
# - This is done using dict() function
# - This function takes the list of period element as argument

# %%
State_list = ['UP', 'HP', 'RAJ']
City_list = ['LUCK', 'SHM', 'JAI']
x = zip(State_list, City_list)
print(dict(x))
# Out:
# {'UP': 'LUCK', 'HP': 'SHM', 'RAJ': 'JAI'}

# %% [markdown]
# Python Identation
# - Identation refers to the space at the beginning of a code line
# - Python uses identation to indicate a block of code
#
#
# ---

# %% [markdown]
# What is Flow Control ?
# - Flow control describe the order in which statements will be execute at runtime
#
# Conditional Statement
# - if - one condition
# - elif - if you want to have multiple conditions
# - else - if all conditions are not satisfied

# %%
age = int(input("Enter your age: "))
if age>60:
   print("you are too old for marry")
elif age<18:
   print("you are too young for marry")
else:
   print("we will find a perfect match for you")
# Out:
# Enter your age: 17
# you are too young for marry

# %%
number = int(input("Enter a number: "))
if number%2==0:
  print("Even Number")
else:
  print("Odd Number")
# Out:
# Enter a number: 4
# Even Number

# %%
password = int(input("Enter a password: "))
if password == 1234:
   print("Access Granted")
else:
   print("Wrong Password")
# Out:
# Enter a password: 1234
# Access Granted

# %%
number_1 = int(input("Enter number one: "))
number_2 = int(input("Enter number two: "))
if number_1 > number_2:
   print("Number one is greater")
elif number_1 < number_2:
   print("Number two is greater")
else:
   print("Both are equal")
# Out:
# Enter number one: 7
# Enter number two: 8
# Number two is greater

# %%
time = float(input("Enter the time: "))
if time >= 6.00 and time < 18.00:
   print("Day Time")
else:
   print("Night Time")
# Out:
# Enter the time: 00.00
# Night Time

# %% [markdown]
# Loop
# - It is use to execute a block of code repeatedly
#
# Primarily there are two types of loop
# - for
# - while
#
#
# ---

# %% [markdown]
# for
# - for loop in python is used to iterate over a sequence(that could be a list,tuple,string, or range of numbers)
# - It execute a set of statements for each item in the sequence
#
# Syntax:
# - for i in object:
#               print()

# %%
# for loop on string
my_sub = "Python"
for i in my_sub:
      print(i)
# Out:
# P
# y
# t
# h
# o
# n

# %%
# for loop on range () function
my_sub = "Python"
for i in range(len(my_sub)):
      print(my_sub[i],i)
# Out:
# P 0
# y 1
# t 2
# h 3
# o 4
# n 5

# %%
# for loop on list
my_list = [100,200,150,300]
for i in my_list:
      print(i)
# Out:
# 100
# 200
# 150
# 300

# %% [markdown]
# while loop
# - It is use to execute a block of code repeatedly until a given condition is satisfied

# %%
i=0
while i<5:
  print(i)
  i+=1
# Out:
# 0
# 1
# 2
# 3
# 4

# %% [markdown]
# Loop Control Statement
# - break - This statement break your loop
# - Continue - This statement skip your current iteration
# - pass - This statement only pass your code

# %%
i=0
while i<6:
  i+=1
  if i==3:
    break
  else:
    print(i)
# Out:
# 1
# 2

# %%
# continue
i=0
while i<6:
    i+=1
    if i==3:
        continue
    else:
        print(i)
# Out:
# 1
# 2
# 4
# 5
# 6

# %%
# pass
i=0
while i<6:
    i+=1
    if i==3:
        pass
        print(i)
    else:
        print(i)
# Out:
# 1
# 2
# 3
# 4
# 5
# 6

# %% [markdown]
# user defined function
# - It  allows you to define functions according to your need
# - These functions are known as user-defined function

# %%
# user defined function without argument
def add():
  a = int(input("Enter first number: "))
  b = int(input("Enter second number: "))
  return a+b

# %%
add()
# Out:
# Enter first number: 8
# Enter second number: 8
# 16

# %% [markdown]
# Positional Arguments
# - If a function has argument then we need to pass these value during call
# of function
# - positional arguments are the arguments that are passed to a function or method in a specific order
# - The order in which you pass these arguments matters, because the function or method will use the arguments in the order that they are received
#
# For example
# - If you have a function that takes two arguments, the first arguments will be used as the first parameter, and the second argument will be used as the second parameter

# %%
# positional arguments
def calculator(a,b):
  print("Addition: ",a+b)
  print("Subtraction: ",a-b)
  print("Multiplication: ",a*b)
  print("Division: ",a/b)
  print("Modulus: ",a%b)
  print("Floor Division: ",a//b)
  print("Exponent: ",a**b)

# %%
calculator(10,5)
# Out:
# Addition:  15
# Subtraction:  5
# Multiplication:  50
# Division:  2.0
# Modulus:  0
# Floor Division:  2
# Exponent:  100000

# %% [markdown]
# Default arguments
# - Default arguments are arguments that are given a default value when the function or method is defined
# - These arguments are optional, because the function or method will use the default value if no value is provided for that argument when the function is called
# - Default arguments can be used to provide default values for optional parameters, or to specify default behaviour for a function or method
# - Python allows us to create functions with parameter that have default values

# %%
def area_perimeter(length=2,breadth=3):
  Area = length * breadth
  Perimeter = 2*(length+breadth)
  print("Area: " +str(Area) + " and Perimeter: " +str(Perimeter))

# %%
area_perimeter()
# Out:
# Area: 6 and Perimeter: 10

# %%
area_perimeter(4,5)
# Out:
# Area: 20 and Perimeter: 18

# %%
area_perimeter(5)
# Out:
# Area: 15 and Perimeter: 16

# %%
area_perimeter(breadth=5)
# Out:
# Area: 10 and Perimeter: 14

# %%
def area_perimeter(length,breadth=3):
  Area = length * breadth
  Perimeter = 2*(length+breadth)
  print("Area: " +str(Area) + " and Perimeter: " +str(Perimeter))

# %%
area_perimeter(4)
# Out:
# Area: 12 and Perimeter: 14

# %% [markdown]
# Keyword arguments
# - keyword arguments are arguments that are passed to a function or method using the name of the arguments followed by an equal sign and the value of the argument
# - These arguments do not need to be passed in a specific order, because the function or method will use the names of the arguments to determine which values to use for which parameters

# %%
def interest(P,R,T):
  Simple_Interest = (P*R*T)/100
  return Simple_Interest

# %%
interest(P=1000,R=10,T=2)
# Out:
# 200.0

# %% [markdown]
# Mixing Positional and Keyword arguments
# - It is possible to mix positional arguments with keyword arguments
# - But the positional arguments cannot appear after any keyword arguments have been defined

# %%
interest(1000,R=10,T=2)
# Out:
# 200.0

# %% [markdown]
# Variable length arguments
# - variable length arguments are a powerful feature in python that makes functions more flexible and adaptable
# - It allows you to create functions that can accept any number of input values, making your code more efficient and user-friendly

# %%
# Non keyword positional variable length arguments
def test(*args):
  print(args)
  print(len(args))
  print(type(args))

# %%
test(2,3,6,9,7,5)
# Out:
# (2, 3, 6, 9, 7, 5)
# 6
# <class 'tuple'>

# %%
def sum_number(*args):
  sum=0
  for num in args:
    sum+=num
    return sum

# %%
sum_number(2,5,7,8)   # Error in result
# Out:
# 2

# %%
# Keyword positional variable length arguments
def test(**kwargs):
  print(kwargs)
  print(len(kwargs))
  print(type(kwargs))

# %%
test(a=10,b=20,c=30,d=40)
# Out:
# {'a': 10, 'b': 20, 'c': 30, 'd': 40}
# 4
# <class 'dict'>

# %%
def pass_students(**kwargs):
  pass_student_list=[]
  for key,value in kwargs.items():
    if value>35:
      pass_student_list.append(key)
  return pass_student_list

# %%
pass_students(Adam=23,Ricky=35,Symond=45,Babu=67,Rambabu=48)
# Out:
# ['Symond', 'Babu', 'Rambabu']

# %% [markdown]
# Numpy
# - Numerical Python
# - It is used for mathematics
# - Data Structure of numpy is multi-dimensional array
# - import numpy as np

# %%
# One dimensional Array
oned_array = np.array([1,2,3,4])
print(oned_array)
# Out:
# [1 2 3 4]

# %%
# Two dimensional Array
twod_array = np.array([[1,2,3,4],[5,6,7,8]])
print(twod_array)
# Out:
# [[1 2 3 4]
#  [5 6 7 8]]

# %%
# ndim --- Find dimension of the array
print(oned_array.ndim)
print(twod_array.ndim)
# Out:
# 1
# 2

# %%
# size --- Represent number of item in the array
print(oned_array.size)
print(twod_array.size)
# Out:
# 4
# 8

# %%
# shape --- Represent shape of the array
print(oned_array.shape)
print(twod_array.shape)
# Out:
# (4,)
# (2, 4)

# %%
# indexing --- location of item
print(oned_array[0])
print(twod_array[1,2])
# Out:
# 1
# 7

# %%
print(twod_array[1][3])
print(twod_array[0:2,0:2])
# Out:
# 8
# [[1 2]
#  [5 6]]

# %%
row_vector = np.array([[1,2,3]])
print(row_vector)
# Out:
# [[1 2 3]]

# %%
column_vector = np.array([[1],[2],[3]])
print(column_vector)
# Out:
# [[1]
#  [2]
#  [3]]

# %%
print(row_vector.transpose())
# Out:
# [[1]
#  [2]
#  [3]]

# %%
mat1 = np.matrix("1,2,3,4;5,6,7,8")
print(mat1)
# Out:
# [[1 2 3 4]
#  [5 6 7 8]]

# %%
zeros_array = np.zeros((3,3), dtype=int)
print(zeros_array)
# Out:
# [[0 0 0]
#  [0 0 0]
#  [0 0 0]]

# %%
ones_array = np.ones((3,3), dtype=int)
print(ones_array)
# Out:
# [[1 1 1]
#  [1 1 1]
#  [1 1 1]]

# %%
print(ones_array*99)
# Out:
# [[99 99 99]
#  [99 99 99]
#  [99 99 99]]

# %%
my_array = np.full((3,3),99)
print(my_array)
# Out:
# [[99 99 99]
#  [99 99 99]
#  [99 99 99]]

# %%
my_array = np.array([1,2,3,4])
print(my_array)
# Out:
# [1 2 3 4]

# %%
power_array = np.power(my_array,2)
print(power_array)
# Out:
# [ 1  4  9 16]

# %%
log_array = np.log(my_array)
print(log_array)
# Out:
# [0.         0.69314718 1.09861229 1.38629436]

# %%
log_array = np.log2(my_array)
print(log_array)
# Out:
# [0.        1.        1.5849625 2.       ]

# %%
log2_array = np.log2(my_array)
print(log2_array)
# Out:
# [0.        1.        1.5849625 2.       ]

# %%
log10_array = np.log10(my_array)
print(log10_array)
# Out:
# [0.         0.30103    0.47712125 0.60205999]

# %%
exp_array = np.exp(my_array)
print(exp_array)
# Out:
# [ 2.71828183  7.3890561  20.08553692 54.59815003]

# %% [markdown]
# Matplotlib
# - It is a python library
# - It is used for data visualisation
# - import matplotlib.pyplot as plt

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
# Line Plot --- It works on numerical data
Xpoint = np.array([1,3])
Ypoint = np.array([2,4])
plt.plot(Xpoint,Ypoint)
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
cgpa = np.array([6,6.5,7,7.8,8,8.6,9,9.2,9.5,10])
package = np.array([4,4.5,5,5.8,6,6.2,6.8,7,7.5,8])
font1 = {'family':'serif','color':'blue','size':20}
font2 = {'family':'serif','color':'darkred','size':15}
plt.plot(cgpa,package,"o:g",ms=15,mec="Orange",mfc="Red",linewidth=2.4)

plt.xlabel("CGPA",fontdict=font1)
plt.ylabel("PACKAGE",fontdict=font2)
plt.title("CGPA VS PACKAGE",fontdict=font2)
plt.show()

# %%
# Bar Plot --- It works on numerical as well as categorical data
Fruit = np.array(["Apple","Banana","Orange","Watermelon"])
Quantity = np.array([80,120,50,100])
colour = np.array(["Red","Yellow","Orange","Green"])
plt.bar(Fruit,Quantity,color= colour)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
Fruit = np.array(["Apple","Banana","Orange"])
Quantity = np.array([100,120,150])
plt.barh(Fruit,Quantity)
plt.show()

# %%
# pieplot --- This plot work on numerical as well as categorical data(pie chart)
Fruit = np.array(["Apple","Banana","Orange","Watermelon"])
Percentage_of_Fruit = np.array([25,20,25,30])
plt.pie(Percentage_of_Fruit, labels= Fruit)
plt.legend(title = "Fruit")
plt.show()

# %%
# scatterplot --- It works on numerical data
#                 Data represent in the form of dot
Age_of_Car = np.array([4,5,6,7,8])
Speed_of_Car = np.array([150,140,130,120,110])
plt.scatter(Age_of_Car, Speed_of_Car)

# %%
# histogramplot --- It shows the frequency distribution of the data
x = np.random.randint(40,100,(1,200))
x = x.flatten()
plt.hist(x, bins = 20)
# Out:
# (array([ 9., 10., 11.,  7., 17., 10., 10.,  9.,  9., 11.,  9.,  5., 11.,
#          8., 11., 11., 14.,  5., 11., 12.]),
#  array([40.  , 42.95, 45.9 , 48.85, 51.8 , 54.75, 57.7 , 60.65, 63.6 ,
#         66.55, 69.5 , 72.45, 75.4 , 78.35, 81.3 , 84.25, 87.2 , 90.15,
#         93.1 , 96.05, 99.  ]),
#  <BarContainer object of 20 artists>)

# %% [markdown]
# Pandas
# - It is a library function
# - It is used for data manipulation and  analysis
#
# Three types of data structure
# - Series - One-dimensional
# - Data Frame - Two-dimensional
# - panel - Three-dimensional
#
# import pandas as pd

# %%
import pandas as pd

# %%
Fruit_list = ["Apple","Banana","Orange","Watermelon"]
my_Series = pd.Series(Fruit_list,name = "Fruit")
my_Series
# Out:
# 0         Apple
# 1        Banana
# 2        Orange
# 3    Watermelon
# Name: Fruit, dtype: object

# %%
List_of_list = [["Apple",100],["Banana,200"],["Orange",150],["Watermelon",80]]
df = pd.DataFrame(List_of_list,columns=["Fruit","Quantity"])
df
# Out:
#         Fruit  Quantity
# 0       Apple     100.0
# 1  Banana,200       NaN
# 2      Orange     150.0
# 3  Watermelon      80.0

# %%
df = pd.read_csv("")

# %% [markdown]
# Supervised machine learning
# - It is a type of machine learning that deals with labelled data
# - It solves two types of problem
#    - Regreesion based Problem
#     - Classification based problem
#
#  Labelled data
#  - There are two types of feature
#    - Input feature/Independent feature
#         -  Eg.---Cgpa
#     - Output feature/Dependent feature/Target value
#         -  Eg.---Package

# %% [markdown]
# Regression based problem
# - In regression based problem the data type of output feature is continuous
#    - Package prediction -------    I/P(CGPA)     ---------   O/P(PACKAGE)
#                                    10                   9.5
#                                    9                     8.4
#                                    7                      7.2

# %% [markdown]
# Classification based problem
# - In this problem the output feature data type is discrete form
#    - Ex---- Result Prediction
#
# *   Marks------ 70  32  65
# *   Result---- pass-1  pass-0 pass-1

# %% [markdown]
# ---
#
#
# Cosine Similarity

# %%
import numpy as np
from numpy.linalg import norm

A = np.array([2, 1, 2, 3, 2, 9])
B = np.array([3, 4, 2, 4, 5, 5])

# compute cosine similarity
cosine = np.dot(A, B) / (norm (A) * norm (B))
print("cosine similarity: ", cosine)
# Out:
# cosine similarity:  0.8188504723485274

# %% [markdown]
# What is Temperature in LLMs ?
#
#  Temperature is a parameter that determines

# %% [markdown]
# Text Summarization

# %%
from transformers import pipeline
summarizer = pipeline("summarization", model = "facebook/bart-large-cnn")

text = '''Artificial intelligence (AI) is a transformative field of computer science dedicated to creating systems capable of performing tasks that typically require human intelligence, such as learning, reasoning, and problem-solving.'''

summary = summarizer(text, max_length=30, min_length=10, do_sample=False)
print(summary[0])
# Out:
# config.json: 0.00B [00:00, ?B/s]
# model.safetensors:   0%|          | 0.00/1.63G [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/363 [00:00<?, ?B/s]
# vocab.json: 0.00B [00:00, ?B/s]
# merges.txt: 0.00B [00:00, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# Device set to use cpu
# {'summary_text': 'Artificial intelligence (AI) is a field of computer science dedicated to creating systems capable of performing tasks that typically require human intelligence. AI'}

# %% [markdown]
# 27/11/25
# -- Practice Questions

# %%
_mylist1 = [1,2,3,4,5]
_mylist1.append(6)
print(_mylist1)
# Out:
# [1, 2, 3, 4, 5, 6]

# %%
_mylist1.remove(6)
print(_mylist1)
# Out:
# [1, 2, 3, 4, 5]

# %%
x = _mylist1.pop(3)
print(x)
# Out:
# 4

# %% [markdown]
# **28/11/25**

# %%
my_list = [10,20,30,40]
my_list[0]= 100
print(my_list)
# Out:
# [100, 20, 30, 40]

# %%
my_list.replace()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipython-input-2363563183.py in <cell line: 0>()
# ----> 1 my_list.replace("10",100)
#
# AttributeError: 'list' object has no attribute 'replace'

# %% [markdown]
# WAP to with the help of slicing in list
# * To print the output from index 1 to 3
# * To print the output from index start to 2
# * To print the output from index 2 to end
# * To print the last three item of the list

# %%
my_list2 = [10, 20, 30, 40, 50, 100]
print(my_list2[1:4])
print(my_list2[:3])
print(my_list2[2:])
print(my_list2[-3:])
# Out:
# [20, 30, 40]
# [10, 20, 30]
# [30, 40, 50, 100]
# [40, 50, 100]

# %%
my_list3 = [10, 20, 30, 40, 50, 60, 70]
print(my_list3[0: :2])
# Out:
# [10, 30, 50, 70]

# %%
print(my_list3[-1:-7:-1])
# Out:
# [70, 60, 50, 40, 30, 20]

# %%
a = [5, 3, 2, 4, 7, 1]
a.sort()
print(a)

a.sort(reverse=True)
print(a)
# Out:
# [1, 2, 3, 4, 5, 7]
# [7, 5, 4, 3, 2, 1]

# %%
# clean() -> Remove all the item from the list
a = [2, 3, 4, 5, 1]
a.clear()
print(a)
# Out:
# []

# %%
for i in range(1,11):
  print(i*i)
# Out:
# 1
# 4
# 9
# 16
# 25
# 36
# 49
# 64
# 81
# 100

# %% [markdown]
# #What is Temperature in LLMs?
# Temperature is a parameter that determines the probability distribution of the next word in text generation. It controlling the randomness and divesity of the output:
#
# ###Low Temperature (e.g., 0.0–0.4):
#  Results are deterministic, precise, and repetitive.
# ###Moderate Temperature (e.g., 0.5–1.0):
#  Outputs become more diverse while maintaining coherence.
# ###High Temperature (e.g., 1.1–2.0):
#  Text becomes creative and experimental, often at the cost of relevance and focus.

# %%
import numpy as np
import matplotlib.pyplot as plt
def softmax_with_temperature(logits, temperature):
    logits = np.array(logits)  # Convert input list to numpy array
    exp_logits = np.exp(logits / temperature) # Scale logits by temperature and exponentiate
    return exp_logits / np.sum(exp_logits)  # Normalize to get probabilities
# Raw scores for 5 tokens
logits = [2.0, 1.0, 0.1, -1.0, -2.0]
temperatures = [0.2, 0.5, 1.0, 2.0]
# Calculate probabilities for each temperature
probabilities = {temp: softmax_with_temperature(logits, temp) for temp in temperatures}
# Plotting
for temp, probs in probabilities.items():
    plt.plot(range(1, len(probs) + 1), probs, label=f'Temperature = {temp}')

plt.title("Effect of Temperature on Softmax Probability Distribution")
plt.xlabel("Token Index")
plt.ylabel("Probability")
plt.legend()
plt.grid()
plt.show()

# %% [markdown]
# #What The Numbers Mean
# Let’s look at the probabilities for different temperatures:
#
# ##Temperature = 0.2 (Very Cold)
# Token 1: 99.3%
#
# Token 2: 0.67%
#
# Other tokens: nearly 0%
#
# This makes the model very focused on the highest-scoring token.
# ##Temperature = 2.0 (Very Hot)
# Token 1: 42.5%
#
# Token 2: 25.8%
#
# Token 3: 16.4%
#
# Token 4: 9.5%
#
# Token 5: 5.8%
#
#  This spreads out the probabilities, making the model more random.

# %% [markdown]
# #Visual Explanation
# The plot shows how temperature affects token selection:
#
# ##Blue line (T=0.2):
# Very steep, almost all probability goes to the highest-scoring token
# ##Orange line (T=0.5):
#  Still favors high-scoring tokens but less extremely
# ##Green line (T=1.0):
#  Moderate distribution
# Red line (T=2.0): Flatter distribution, giving more chances to lower-scoring tokens

# %% [markdown]
# #Example of how temperature works in text generation (Using GROQ API)
#
# Below is a simple python code which uses GROQ API for accessing LLAMA 3.3 70B parameter model.

# %%
# !pip install groq
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 137.5/137.5 kB 6.9 MB/s eta 0:00:00
# ...

# %% [markdown]
# ###GROQ
# GROQ (short for Generative Retrieval Optimized Query) is a chip and AI inference engine developed by Groq Inc.
#
# It's not a model, but hardware and software optimized to run AI models super fast, especially large language models (LLMs).
#
# Think of it like this: if LLaMA is a powerful brain, then GROQ is a lightning-fast body helping it move.
#
# Groq is known for ultra-low latency, meaning it can return responses almost instantly, which is perfect for real-time AI chatbots, robotics, and edge AI.

# %% [markdown]
# ##LLaMA
# LLaMA stands for Large Language Model Meta AI.
#
# It's an open-source language model family developed by Meta (Facebook).
#
# Similar to OpenAI’s GPT models, it can do:
#
# Text generation
#
# Summarization
#
# Translation
#
# Coding
#
# Reasoning, etc.
#
# There are different versions: LLaMA 1, 2, and 3 (latest as of 2024).
#
# LLaMA models are trained on huge datasets and optimized to run efficiently, even on smaller hardware (compared to GPT-4).

# %%
import numpy as np
from groq import Groq
def generate_completion(client, model, prompt, temperature):
    completion = client.chat.completions.create(
        model=model,
        messages=[{"role": "user", "content": prompt}],
        temperature=temperature,
        max_tokens=100,
        top_p=1,
        stream=False,
        stop=None,
    )
    return completion.choices[0].message.content

def main():
    client = Groq(api_key="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")
    model = "llama-3.3-70b-versatile"
    prompt = "Explain AI in exactly 50 words. Do not exceed this limit."
# Generate temperatures from 0 to 2 with a step of 0.1
    temperatures = np.arange(0, 2.1, 0.1)
    for temp in temperatures:
        print(f"\nTemperature: {temp:.1f}")
        result = generate_completion(client, model, prompt, temp)
        print(result)
#divider line
        print("-" * 50)
if __name__ == "__main__":
    main()
# Out:
# Temperature: 0.0
# Artificial Intelligence (AI) refers to computer systems that mimic human intelligence, learning, and problem-solving. AI uses algorithms, data, and machine learning to perform tasks, make decisions, and improve over time, enabling automation, innovation, and efficiency in various industries and applications, transforming the way we live and work.
# --------------------------------------------------
#
# Temperature: 0.1
# Artificial Intelligence (AI) refers to computer systems that mimic human intelligence, learning, and problem-solving. AI uses algorithms, data, and machine learning to perform tasks, make decisions, and improve over time, enabling automation, innovation, and efficiency in various industries and applications, transforming the way we live and work.
# --------------------------------------------------
#
# Temperature: 0.2
# ...

# %% [markdown]
# client.chat.completions.create(...)
#
# client: This is your Groq client (already authenticated with your API key).
#
# .chat: You're using the chat endpoint (for conversational prompts, like ChatGPT).
#
# .completions: Refers to chat-based completions (responses to messages).
#
# .create(...): This method sends a new request to generate a completion.

# %% [markdown]
#  top_p=1 — Nucleus Sampling (a.k.a. "top-p sampling")
#
# Purpose: Controls how many of the most likely words are considered when picking the next token.
#
# top_p sets a cumulative probability threshold.

# %% [markdown]
# ![top llma.png](data:image/png;base64,...)

# %% [markdown]
# ![Screenshot 2025-04-25 131737.png](data:image/png;base64,...)

# %%
import nltk
nltk.download('punkt')
nltk.download('punkt_tab') # Add this line to download the missing resource
from nltk.tokenize import word_tokenize

sentence = "Machine learning is fun!"
tokens = word_tokenize(sentence)

print("Tokens:", tokens)
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt_tab.zip.
# Tokens: ['Machine', 'learning', 'is', 'fun', '!']

# %%
from transformers import BertTokenizer

# Load pretrained tokenizer
tokenizer = BertTokenizer.from_pretrained('bert-base-uncased')

sentence = "Unhappiness is contagious."
tokens = tokenizer.tokenize(sentence)

print("Subtokens:", tokens)
# Out:
# Subtokens: ['un', '##ha', '##pp', '##iness', 'is', 'con', '##tag', '##ious', '.']

# %%
import numpy as np
from numpy.linalg import norm

A = np.array([2, 1, 2, 3, 2, 9])
B = np.array([3, 4, 2, 4, 5, 5])

# compute cosine similarity
cosine = np.dot(A, B) / (norm(A) * norm(B))
print("Cosine Similarity:", cosine)
# Out:
# Cosine Similarity: 0.8188504723485274

# %%
from transformers import AutoTokenizer

# Load a tokenizer (e.g., BERT)
tokenizer = AutoTokenizer.from_pretrained("bert-base-uncased")

text = "Machine learning is transforming materials science!"

# Tokenize
tokens = tokenizer.tokenize(text)
token_ids = tokenizer.encode(text)

print("Tokens:", tokens)
print("Token IDs:", token_ids)
# Out:
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# tokenizer_config.json:   0%|          | 0.00/48.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/570 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/466k [00:00<?, ?B/s]
# Tokens: ['machine', 'learning', 'is', 'transforming', 'materials', 'science', '!']
# Token IDs: [101, 3698, 4083, 2003, 17903, 4475, 2671, 999, 102]

# %% [markdown]
# What is Text Summarization?
#
# Text summarization is the process of generating a shorter version of a text that preserves its main meaning, key ideas, and intent.
#
# It’s a form of text generation, where the model takes a long input (like an article, report, or paragraph) and generates a concise summary, just like a human would do.

# %% [markdown]
# Two Main Types of Text Summarization
# 1. Extractive Summarization
#
# The model selects important sentences or phrases directly from the original text.
#
# It does not generate new sentences; it simply extracts and rearranges existing content.
#
# Example:
# Input:
#
# "The Indian Space Research Organisation (ISRO) launched the Chandrayaan-3 mission to explore the Moon's south pole. The mission aims to demonstrate safe landing and roving on the lunar surface."
# Extractive summary:
# "ISRO launched Chandrayaan-3 to explore the Moon's south pole."

# %% [markdown]
# . Abstractive Summarization
#
# The model understands the text and generates new sentences that express the same meaning — like how humans paraphrase.
#
# It’s a truly generative approach.
#
# Example:
# Input:
#
# "The Indian Space Research Organisation (ISRO) launched the Chandrayaan-3 mission to explore the Moon's south pole. The mission aims to demonstrate safe landing and roving on the lunar surface."
# Abstractive summary:
# "ISRO’s Chandrayaan-3 mission targets a soft landing on the Moon’s south pole."
#
# 🧩 Common models:
#
# Transformer-based models like T5, BART, PEGASUS, GPT, LLaMA, etc.

# %% [markdown]
# ⚙️ How It Works in Generative AI
#
# Generative AI models (like GPT, BART, T5) are trained on large datasets of (document, summary) pairs.
#
# Input: A long text.
#
# Encoder: Understands the meaning of the input text.
#
# Decoder: Generates a shorter version that preserves meaning.
#
# Training objective: Minimize the difference between generated summary and reference summary.

# %% [markdown]
# Applications of Text Summarization
#
# News summarization – Summarizing news articles.
#
# Research summarization – Summarizing scientific papers or abstracts.
#
# Legal/medical summarization – Condensing long legal documents or patient histories.
#
# Customer service – Summarizing support tickets or chat transcripts.
#
# Meeting summarization – Summarizing transcripts from meetings or lectures.

# %%
from transformers import pipeline

summarizer = pipeline("summarization", model="facebook/bart-large-cnn")

text = """The global shift toward renewable energy is accelerating,
driven by concerns over climate change and energy security. Solar
and wind power installations have reached record levels worldwide."""

summary = summarizer(text, max_length=30, min_length=10, do_sample=False)
print(summary[0])
# Out:
# config.json: 0.00B [00:00, ?B/s]
# model.safetensors:   0%|          | 0.00/1.63G [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/363 [00:00<?, ?B/s]
# vocab.json: 0.00B [00:00, ?B/s]
# merges.txt: 0.00B [00:00, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# Device set to use cpu
# {'summary_text': 'Solar and wind power installations have reached record levels worldwide. The global shift toward renewable energy is accelerating.'}

# %%
#from transformers import pipeline

# %% [markdown]
# This line imports the pipeline function from the Hugging Face Transformers library.
#
# The Transformers library provides pre-trained models for:
#
# Text summarization
#
# Text classification
#
# Sentiment analysis
#
# Translation
#
# Image classification
#
# Question answering
#
# Text generation (GPT-like models)
#
# Many more…
#
# The pipeline function is a shortcut tool that makes it very easy to use pre-trained models without needing to write complex code.
#
# ✅ Why use pipeline?
#
# Because it:
#
# ✔ Loads a pre-trained model automatically
#
# You don’t need to manually load the tokenizer and model.
#
# ✔ Automatically handles tokenization
#
# It converts your text to tokens internally.
#
# ✔ Runs the model
#
#
#
# ✔ Returns clean, human-readable output

# %% [markdown]
# do_sample=False
#
# This disables sampling and uses greedy decoding.
#
# 🔍 What is greedy decoding?
#
# The model picks the highest-probability next word at each step.
#
# Output is deterministic → same input → same summary every time.
#
# No randomness.
#
# If you set do_sample=True, the model would generate more diverse and creative summaries (but may vary each time).
